# %%
import numpy as np

# %% [markdown]
# ### Statistics

# %%
stats = np.array([[1,2,3],[4,5,6]])
stats
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
print(np.min(stats))
print(np.max(stats))


print(np.min(stats, axis=1))
print(np.min(stats, axis=0))
# Out:
# 1
# 6
# [1 4]
# [1 2 3]

# %%
print(np.sum(stats))
# Out:
# 21
