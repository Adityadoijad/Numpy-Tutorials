# %%
import numpy as np

# %% [markdown]
# ### Mathematics

# %%
a=np.array([1,2,3,4])
print(a)
# Out:
# [1 2 3 4]

# %%
a+2
# Out:
# array([3, 4, 5, 6])

# %%
a-2
# Out:
# array([-1,  0,  1,  2])

# %%
a*2
# Out:
# array([2, 4, 6, 8])

# %%
a/2
# Out:
# array([0.5, 1. , 1.5, 2. ])

# %%
b=np.array([1,0,1,0])
a+b
# Out:
# array([2, 2, 4, 4])

# %%
a**2
# Out:
# array([ 1,  4,  9, 16])

# %%
#take sins and cosins

print(np.sin(a))
print(np.cos(a))
# Out:
# [ 0.84147098  0.90929743  0.14112001 -0.7568025 ]
# [ 0.54030231 -0.41614684 -0.9899925  -0.65364362]
