# %% [markdown]
# # Numpy

# %% [markdown]
# ### Loading Numpy

# %%
import numpy as np

# %% [markdown]
# ### Array

# %%
#Creating Array

#1d
a=np.array([1,2,3])
print(a)

print()

#2d
b=np.array([[1,2,3],[4,5,6]])
print(b)
# Out:
# [1 2 3]
#
# [[1 2 3]
#  [4 5 6]]

# %%
#GEt dimentions of an array
b.ndim
# Out:
# 2

# %%
# get shape
print(b.shape)
print(a.shape)
# Out:
# (2, 3)
# (3,)

# %%
# get type
b.dtype
# Out:
# dtype('int64')

# %%
#get size
a.itemsize
# Out:
# 8

# %%
#get total size
a.size
# Out:
# 3
